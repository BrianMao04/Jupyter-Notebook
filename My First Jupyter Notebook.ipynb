# %%
print("Jupyter Notebook can be very useful for code visualization, like generating a whole bunch of plots. Heavily used in data science.")
# Out:
# Jupyter Notebook can be very useful for code visualization, like generating a whole bunch of plots. Heavily used in data science.

# %%
print("I'm a code cell. Typing out code right now. Run this by clicking the run button.")
# Out:
# I'm a code cell. Typing out code right now. Run this by clicking the run button.

# %%
print("Order in which lines have been indicated or noted by the numbers on the left.")
# Out:
# Order in which lines have been indicated or noted by the numbers on the left.

# %%
print("dd to delete line. Shift K and J to highlight multiple lines to run at once.")
# Out:
# dd to delete line. Shift K and J to highlight multiple lines to run at once.

# %%
print("Could have done MTE 544 assignments using this. The jupyter notebook file itself can be shared and viewed in the nbviewer.")
# Out:
# Could have done MTE 544 assignments using this. The jupyter notebook file itself can be shared and viewed in the nbviewer.

# %%
from pylab import *

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %%
subplot(1,2,1)
plot(x, y, 'r--')
subplot(1,2,2)
plot(y, x, 'g*-');

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');

# %%
fig.savefig("Saved MatPlotLib Figure From Running Jupyter Notebook.png")

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-aa6c9ba9ebcf> in <module>
#       4 ax = fig.add_subplot(1, 2, 1, projection='3d')
#       5
# ----> 6 p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)
#       7
#       8 # surface_plot with color grading and color bar
#
# NameError: name 'X' is not defined

# %%
print ("Lots of things can be done with matplotlib library. Easier to visualize within the code itself using Jupyter Notebook.")
# Out:
# Lots of things can be done with matplotlib library. Easier to visualize within the code itself using Jupyter Notebook.
